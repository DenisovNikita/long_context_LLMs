# %% [markdown]
# ### Imports & Definitions

# %%
import sys
sys.path.append("../../utils")
from definitions import *
from matplotlib_helpers import plot_tokens_distributions

# %% [markdown]
# ### Visualize tokens graphic

# %%
plot_tokens_distributions(ARTIFACTS_DIR_PATH.joinpath("tokens/full_russian_diplomas_stupid_filter"), vlines_blue=[4000, 8000, 16000, 32000], vlines_red=[64000, 128000])

# %%
plot_tokens_distributions(ARTIFACTS_DIR_PATH.joinpath("tokens/full_russian_diplomas_stupid_filter_abstract"), vlines_blue=[4000, 8000, 16000, 32000], vlines_red=[64000, 128000])

# %%
plot_tokens_distributions(ARTIFACTS_DIR_PATH.joinpath("tokens/full_russian_diplomas_2023_stupid_filter"), vlines_blue=[4000, 8000, 16000, 32000], vlines_red=[128000])

# %%
plot_tokens_distributions(ARTIFACTS_DIR_PATH.joinpath("tokens/full_russian_diplomas_2023_stupid_filter_abstract"), vlines_blue=[4000, 8000, 16000, 32000], vlines_red=[64000, 128000])
