# %% [markdown]
# ### Imports & Definitions

# %%
import sys
sys.path.append("../../utils")
from definitions import *

# %% [markdown]
# ### Read results

# %%
df = pd.read_csv(ARTIFACTS_DIR_PATH.joinpath("metrics/knowledge_tests/obrazovaka_full_results.csv"))

# %%
llama2 = df[df["model"] == "llama2"]
llama2["percent"].mean()
# Out:
# 23.239333333333335

# %%
llama3 = df[df["model"] == "llama3"]
llama3["percent"].mean()
# Out:
# 38.707333333333324

# %%
df = pd.read_csv(ARTIFACTS_DIR_PATH.joinpath("junk/some_results_stupid.csv"))
df
# Out:
#     Unnamed: 0   model                                          test_path  \
# 0            0  llama2  ../../metrics/knowledge_tests/obrazovaka/the_d...
# 1            1  llama2  ../../metrics/knowledge_tests/obrazovaka/the_b...
# 2            2  llama2  ../../metrics/knowledge_tests/obrazovaka/and_q...
# 3            3  llama2  ../../metrics/knowledge_tests/obrazovaka/oblom...
# 4            4  llama2  ../../metrics/knowledge_tests/obrazovaka/eveni...
# 5            5  llama2  ../../metrics/knowledge_tests/obrazovaka/docto...
# 6            6  llama2  ../../metrics/knowledge_tests/obrazovaka/war_a...
# 7            7  llama2  ../../metrics/knowledge_tests/obrazovaka/the_m...
# 8            8  llama2  ../../metrics/knowledge_tests/obrazovaka/dead_...
# 9            9  llama2  ../../metrics/knowledge_tests/obrazovaka/the_g...
# 10          10  llama2  ../../metrics/knowledge_tests/obrazovaka/the_w...
# 11          11  llama2  ../../metrics/knowledge_tests/obrazovaka/the_h...
# ...

# %%
llama2 = df[df["model"] == "llama2"]
llama2["percent"].mean()
# Out:
# 23.646666666666665

# %%
llama3 = df[df["model"] == "llama3"]
llama3["percent"].mean()
# Out:
# 33.69733333333333

# %%
df = pd.read_csv(ARTIFACTS_DIR_PATH.joinpath("junk/some_results_briefly.csv"))
df
# Out:
#     Unnamed: 0   model                                          test_path  \
# 0            0  llama2  ../../metrics/knowledge_tests/obrazovaka/the_d...
# 1            1  llama2  ../../metrics/knowledge_tests/obrazovaka/the_b...
# 2            2  llama2  ../../metrics/knowledge_tests/obrazovaka/and_q...
# 3            3  llama2  ../../metrics/knowledge_tests/obrazovaka/oblom...
# 4            4  llama2  ../../metrics/knowledge_tests/obrazovaka/eveni...
# 5            5  llama2  ../../metrics/knowledge_tests/obrazovaka/docto...
# 6            6  llama2  ../../metrics/knowledge_tests/obrazovaka/war_a...
# 7            7  llama2  ../../metrics/knowledge_tests/obrazovaka/the_m...
# 8            8  llama2  ../../metrics/knowledge_tests/obrazovaka/dead_...
# 9            9  llama2  ../../metrics/knowledge_tests/obrazovaka/the_g...
# 10          10  llama2  ../../metrics/knowledge_tests/obrazovaka/the_w...
# 11          11  llama2  ../../metrics/knowledge_tests/obrazovaka/the_h...
# ...

# %%
llama2 = df[df["model"] == "llama2"]
llama2["percent"].mean()
# Out:
# 19.474666666666668

# %%
llama3 = df[df["model"] == "llama3"]
llama3["percent"].mean()
# Out:
# 53.434
