# %% [markdown]
# ### Imports & Definitions

# %%
import sys
sys.path.append("../../utils")
from definitions import *

# %% [markdown]
# ### Read df

# %%
df = pd.read_csv(ARTIFACTS_DIR_PATH.joinpath("diplomas_abstracts/mcs_raw_learnt_abstract.csv"))
df.head()
# Out:
#    Unnamed: 0     id  year                                            diploma  \
# 0          12  45042  2023  АЙВАЗЬЯН Аршак Владимирович\nВыпускная квалифи...
# 1          25  45043  2023  Санкт-Петербургский государственный университе...
# 2          37  45044  2023  Санкт-Петербургский государственный университе...
# 3         101  45046  2023  Санкт-Петербургский государственный университе...
# 4         152  45047  2023  Санкт–Петербургский государственный университе...
#
#                                             abstract  \
# 0  В этой работе мы строим правую трансферную мод...
# 1  Пусть 𝐾 выпуклое тело в ℝ^𝑛. Определим 𝑑𝑛,𝑛−1(...
# 2  Работа посвящена повышению производительности ...
# 3  В работе мы обобщаем результаты об энергии нат...
# 4  В рамках данной работы рассматривается подход ...
#
#                         study_field            degree  \
# 0  MATHEMATICS AND COMPUTER SCIENCE  BACHELOR STUDIES
# 1  MATHEMATICS AND COMPUTER SCIENCE  BACHELOR STUDIES
# ...

# %%
for _, row in df.iterrows():
    print("abstract:", row["abstract"])
    print("raw_model:", row["raw_model"])
    print("learnt:", row["learnt"])
    print()
# Out:
# abstract: В этой работе мы строим правую трансферную модельную структуру на категории алгебр обогащенной алгебраической теории в обогащенной модельной категории, удовлетворяющей некоторым свойствам. Также мы даем несколько общих конструкций генерирующих замкнутые симметричные моноидальные локально конечно представимые категори, которые служат базой обогащения.
# raw_model: В работе рассматривается модельная структура на категории алгебр над теорией Ловера. Рассматриваются различные приложения этой структуры, в частности, к теории групп, теории модулей над полями, теории групп Ли, к теории модулей над полями, к теории алгебр над полями и т.д.</s>
# learnt: В данной работе рассматривается модельная структура алгебр над теорией Ловера.</s>
#
# ...
