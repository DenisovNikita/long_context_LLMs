# %% [markdown]
# ### Install & Import & Define

# %%
! pip install --upgrade --quiet  langchain-openai tiktoken chromadb langchain
! pip install deep-translator
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: deep-translator in /opt/homebrew/lib/python3.11/site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /opt/homebrew/lib/python3.11/site-packages (from deep-translator) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/homebrew/lib/python3.11/site-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.5.7)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import os
import sys
from pathlib import Path
from typing import List, Any
from langchain.chains.summarize import load_summarize_chain
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.llms import Ollama
from langchain.docstore.document import Document
from deep_translator import GoogleTranslator

# %%
BOOK_PATH = "../../downloaded_books/txt/the_heart_of_a_dog.txt"

# %% [markdown]
# ### Splitting book

# %%
path = Path(BOOK_PATH)

# %%
with open(path, "r") as f:
    data = f.read()

# %%
len(data)
# Out:
# 41811

# %%
def split_data(data: str, max_symbols) -> List[str]:
    parts = []
    for i in range(0, len(data), max_symbols):
        parts.append(data[i:i+max_symbols])
    return parts

# %%
parts = split_data(data, 4000)
len(parts[0]), len(parts[-1])
# Out:
# (4000, 1811)

# %% [markdown]
# ### Summarize function

# %%
def get_summaries(parts: List[str], chain) -> List[str]:
    res = chain.invoke([Document(page_content=part) for part in parts])
    print(res.keys())
    print(len(res["input_documents"]))
    print(res["input_documents"][1].page_content[:100], res["input_documents"][2].page_content[:100])
    return res["output_text"]

# %%
docs = chain.invoke([Document(page_content="kek")])["input_documents"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 docs = chain.invoke([Document(page_content="kek")])["input_documents"]
#
# NameError: name 'chain' is not defined

# %% [markdown]
# ### Summarize logic

# %%
def recursive_summarization(data: str, chain: Any, max_symbols=4000) -> str:
    print(f"len(data) = {len(data)}, wanted <= {max_symbols}")
    if len(data) == 0:
        return data
    parts = split_data(data, max_symbols)
    if len(parts) == 1:
        return parts[0]
    parts_summaries = get_summaries(parts, chain)
    return recursive_summarization(''.join(parts_summaries), chain, max_symbols)

# %% [markdown]
# ### Function for summarize book

# %%
def get_book_summary(book_path: str) -> str:
    with open(book_path, "r") as f:
        data = f.read()
    print(data[:100])
    llm = Ollama(model="llama2")
    chain = load_summarize_chain(llm, chain_type="stuff")
    summary = recursive_summarization(data, chain)
    print(summary)
    # return summary
    translated = GoogleTranslator(source='auto', target='ru').translate(summary)
    return translated

# %%
get_book_summary("../../downloaded_books/txt/and_quiet_flows_the_don.txt")
# Out:
# Annotation
#
#
# Роман-эпопея Михаила Шолохова «Тихий Дон» – одно из наиболее значительных, масштабных и
# len(data) = 703955, wanted <= 4000
# dict_keys(['input_documents', 'output_text'])
# 176
# го по хутору чудно́е. Ребятишки, пасшие за прогоном телят, рассказывали, будто видели они, как Проко а.
#
#
#
#
#
# * * *
#
#
# Жена Прокофия умерла вечером этого же дня. Недоношенного ребенка, сжалившись, взяла
# len(data) = 130, wanted <= 4000
#
# The summary is not available for this book as it is an excerpt from a larger work and does not have a concise summary on its own.
# 'Краткое изложение для этой книги недоступно, поскольку оно представляет собой отрывок из более крупной работы и не содержит отдельного краткого изложения.'

# %%
for path in Path("../../downloaded_books/txt/").glob("*.txt"):
    print(f"Getting summary of {path.stem}")
    summary = get_book_summary(path)
    print(f"Summary of {path.stem} = '{summary}'")
    dir = Path("../../downloaded_books/stupid_summaries_separate_chain/")
    dir.mkdir(parents=True, exist_ok=True)
    with open(f"{dir}/{path.stem}.txt", "w") as f:
        f.write(summary)
# Out:
# Getting summary of doctor_zhivago
# len(data) = 105968, wanted <= 4000
# len(data) = 669, wanted <= 4000
# Summary of doctor_zhivago = 'Краткое содержание предоставленного текста:
#
# Лара — молодая женщина, работающая официанткой в ​​ресторане. Она недовольна своей жизнью и чувствует себя в ловушке из-за своей работы и отношений со своим парнем Комаровским. Она мечтает уйти с работы и начать новую жизнь, но не может принять меры из-за финансовой зависимости от Комаровского. Она чувствует себя задыхающейся от его собственнического и контролирующего поведения и жаждет свободы и независимости. Несмотря на свое несчастье, Лара остается пассивной и принимает свою ситуацию, чувствуя себя бессильной ее изменить. Текст представляет собой обзор жизни и эмоций Лары, подготавливая почву для остальной части истории.'
# Getting summary of evenings_on_a_farm_near_dikanka
# len(data) = 132973, wanted <= 4000
# len(data) = 1826, wanted <= 4000
# Summary of evenings_on_a_farm_near_dikanka = 'Это list 48 Russian words and phrases with their meanings and explanations. Слова являются в основном связаны с ежедневной жизнью, природой, и человеческими характеристиками, і деякими з них мають ironic або humorous connotations. Здесь есть слова и свои средства:
#
# 1. Хтери - "To want" (rus.)
# 2. Секу - "Fast" (rus.)
# 3. Волки – "Wolf" (rus.)
# 4. Кругом – "Around" (ukr.)
# 5. Кошки - "Cats" (rus.)
# 6. Собаки – "Dogs" (rus.)
# 7. Люди – "People" (ukr.)
# 8. Птицы - "Birds" (rus.)
# 9. Вода – "Water" (ukr.)
# 10. Земля - ​​"Earth" (rus.)
# 11. Небо – "Sky" (rus.)
# 12. Снег – "Snow" (ukr.)
# 13. Холод – "Cold" (ukr.)
# 14. Весна – "Spring" (rus.)
# 15. Лето – "Summer" (rus.)
# 16. Зима – "Winter" (rus.)
# 17. Сетка - "Net" (rus.)
# 18. Возить – "Carry" (rus.)
# 19. Полагай - "Lay" (rus.)
# 20. Сияя - "Shining" (rus.)
# 21. Сякавица - "Smallness" (rus.)
# 22. Дробь - "Dirt" (rus.)
# 23. Зелень - "Green" (rus.)
# 24. Квадрат – "Square" (rus.)
# 25. Ровно - "Even" (rus.)
# 26. Неparen - "Uneven" (rus.)
# 27. Высокая - "Tall" (rus.)
# 28. Низкая – "Low" (rus.)
# 29. Тяжелая - "Heavy" (rus.)
# 30. легкая – "Light" (rus.)
# 31. Соломяк - "Flaky" (rus.)
# 32. Страсть - "Ignited" (rus.)
# 33. Угасать – "To fade away" (rus.)
# 34. Созидать - "To happen" (rus.)
# 35. Создаться – "To be born" (rus.)
# 36. Возникать – "To emerge" (rus.)
# 37. Угасать - "To disappear" (rus.)
# 38. Затекть – "To frost over" (rus.)
# 39. Заморозить – "To freeze over" (rus.)
# 40. Погасить – "To melt away" (rus.)
# 41. Сириты – "To darken" (rus.)
# 42. Зелениты – "To green" (rus.)
# 43. Голуби - "To blue" (rus.)
# 44. Порисовать – "To slowly disappear" (rus.)
# 45. Утекать - "To trickle away" (rus.)
# 46. ​​Сиритеты – "To darken" (rus.)
# 47. Зеленититы – "To green" (rus.)
# 48. Голубиты - "To blue" (rus.)
#
# Note: Некоторые слова должны иметь множественные средства или коннотации, и некоторые могут быть регион-specific или colloquial.'
# Getting summary of the_dawns_here_are_quiet
# len(data) = 281563, wanted <= 4000
# len(data) = 648, wanted <= 4000
# Summary of the_dawns_here_are_quiet = 'В тексте представлено краткое изложение событий, приведших к началу Второй мировой войны 22 июня 1941 года. В нем описывается, как жители многоквартирного дома в Москве были разбужены звуками взрывов и стрельбы, указывающими на то, что находившийся неподалеку военный складское помещение пострадало. В тексте также подчеркивается страх и растерянность персонажей, пытающихся разобраться в хаосе вокруг них.
#
# Основное внимание в тексте уделяется персонажу Коле, который полон решимости присоединиться к борьбе с немецким вторжением, несмотря на то, что находится в полной гражданской одежде. Текст заканчивается тем, что Коля выбегает из здания, чтобы вступить в бой.'
# Getting summary of the_heart_of_a_dog
# len(data) = 41811, wanted <= 4000
# len(data) = 605, wanted <= 4000
# Summary of the_heart_of_a_dog = 'Группа жильцов многоквартирного дома беседует с профессором Филиппом Филипповичем, который расстроен тем, что его просят пожертвовать деньги детям Франции. Он отказывается сделать это, ссылаясь на свою неприязнь к пролетариату. Остальные жители пытаются его урезонить, но он остается равнодушным. Один из них предлагает ему взглянуть на ситуацию под другим углом, но тот перебивает его и говорит, что ему это неинтересно. Разговор заканчивается тем, что профессор Филипп Филиппович выбегает из комнаты, оставив остальных в замешательстве и разочаровании.
#
# КОНЕЦ'
# Getting summary of oblomov
# len(data) = 225023, wanted <= 4000
# len(data) = 678, wanted <= 4000
# Summary of oblomov = 'Краткое содержание «Главы 1: Видение» в «Преступлении и наказании» Федора Достоевского таково:
#
# Рассказчик, юноша по имени Ильич, видит себя тринадцатилетним мальчиком, посещающим пансионат в Верхлёве, где знакомится с мальчиком по имени Обломов, который из-за золотого языка не может ходить в школу. Ильич отмечает, что дети в пансионате окружены странной атмосферой, которая влияет на их развитие и поведение. Он задается вопросом, были бы они другими, если бы ходили в школу в другом городе.
#
# Видение заканчивается тем, что Ильич осознает, что его все еще преследуют воспоминания о детстве, несмотря на то, что он стал старше.'
# Getting summary of idiot
# len(data) = 317970, wanted <= 4000
# len(data) = 921, wanted <= 4000
# Summary of idiot = 'Благодарим вас за предоставленный текст «Дело о проклятом золоте». Я подготовил краткое изложение текста ниже. Обратите внимание, что данное резюме не является всесторонним анализом, а скорее кратким обзором основных моментов текста.
#
# «Дело о проклятом золоте» — рассказ Леонида Андреева. Рассказчик, молодой офицер, рассказывает о своем опыте стать свидетелем смерти старухи, известной своим богатством и щедростью. Смерть старухи окутана тайной, поскольку незадолго до ее кончины ее видели смеющейся и улыбающейся. Рассказчик размышляет о смысле жизни и смерти и о том, как они переплетаются с нашим опытом и восприятием. Он также борется со своей виной и ответственностью за смерть старухи, которая, по его мнению, каким-то образом связана с его собственными действиями. В целом история поднимает вопросы о природе человеческого существования и хрупкости жизни.'
# Getting summary of crime_and_punishment
# len(data) = 262557, wanted <= 4000
# len(data) = 2210, wanted <= 4000
# Summary of crime_and_punishment = 'Это список из 29 слов и фраз русского языка, а также их значений и объяснений для каждого из них. Слова часто юмористические или ироничные, а некоторые используются в игривой или саркастической манере. Вот краткое изложение основных моментов, затронутых в этом документе:
#
# 1. Циммерман (Tsimmermann) – известный в Петербурге фабрикант.
# 2. Кацавейка (Katsavyika) – короткая теплая шубка.
# 3. Билетик (Biletik) – рубль.
# 4. Укладка (Ukladka) – небольшой сундучок.
# 5. Сибирка (Sibirka) – разновидность длинного, свободного кроя пальто.
# 6. Нанковая (Nankova) – особый вид хлопчатобумажной ткани.
# 7. «Физиология» Льюиса (Fiziologiya Lvivisa) — книга английского философа и физиолога Д. Г. Льюиса на тему повседневной жизни.
# 8. Бурнус (Burnus) – разновидность плаща свободного кроя.
# 9. Драдедам (Dradedam) – тонкая, легкая ткань.
# 10. «Хуторок» (Хоторк) — популярная песня Э. Климовского.
# 11. Лот (Lot) — старинная русская единица веса, равная 12,797 граммам.
# 12. Скалдырничать (Scaldyrnichat) - нервно или суетливо болтать.
# 13. Орден Святая Анны (Орден Святой Анны) — российская военная награда.
# 14. Кичка (Киха) - традиционный головной платок замужних женщин.
# 15. Коты (Koty) – вид теплой, удобной обуви.
# 16. Рост человека (Rost cheloveka) - рост человека, измеряемый в аршинах (71 см) и верстах (4,44 см).
# 17. Гарнитур (Garniturn) – плотная, роскошная ткань.
# 18. Квартальный надзиратель (Квартальный надзиратель) - офицер полиции низшего ранга, отвечающий за небольшой участок.
# 19. Хожалые (Хожаллые) - полицейские низшего ранга, выполнявшие функции связных или бегунов.
# 20. Благодарю (Благодарю) — фраза, используемая для выражения благодарности.
# 21. Присутствие (Пресёрность) - место службы в государственном учреждении.
# 22. Пенные (Penny) – штраф или неустойка.
# 23. Смирительный дом (Smirirentny dom) - тюрьма или работный дом.
# 24. Будируя (Будирюя) - ворчать или жаловаться.
# 25. «Исповедь» Руссо (Ispovenie Russo) — книга Жан-Жака Руссо.
# 26. Выжига (Выжига) - бездельник или тунеядец.
# 27. Головка (Головка) – женский платок.
# 28. Вояжирует (Вояжирует) - мечтать или фантазировать.
# 29. Авенантненькая (Авенантненькая) - слово, обозначающее что-то приятное или привлекательное.'
# Getting summary of the_master_and_margarita
# len(data) = 181939, wanted <= 4000
# len(data) = 1148, wanted <= 4000
# Summary of the_master_and_margarita = 'Краткое содержание отрывка из книги следующее:
#
# * Рассказчик Коровьев встречается с человеком по имени Никанор Иванович, который является председателем совета директоров турфирмы.
# * Коровьев убеждает Никанора Ивановича снять ему виллу в Ницце на неделю, обещая заплатить крупную сумму денег.
# * Коровьев с виду богатый и влиятельный человек, но на самом деле он обманщик, не собирающийся платить за квартиру.
# * Никанор Иванович убедился в гладкой речи Коровьева и соглашается снять ему виллу.
# * Коровьев подписывает контракт с Никанором Ивановичем, но быстро понимает, что его обманули и контракт недействителен.
# * Коровьев покидает агентство, оставляя Никанора Ивановича в состоянии растерянности и смущения.
#
# Основными темами отрывка являются обман, обман и динамика власти между двумя персонажами. Коровьев изображен хитрым и манипулирующим человеком, а Никанор Иванович доверчивым и легко обманываемым. Отрывок также затрагивает идею противостояния видимости и реальности, поскольку богатое и влиятельное поведение Коровьева оказывается лишь фасадом.'
# Getting summary of the_brothers_karamazov
# len(data) = 438866, wanted <= 4000
# len(data) = 290, wanted <= 4000
# Summary of the_brothers_karamazov = 'Я не могу предоставить краткое изложение предоставленного вами текста, поскольку он не является полным и связным. Текст представляет собой набор разрозненных фраз и предложений без четкой структуры и смысла. Пожалуйста, предоставьте полный и связный текст, чтобы я мог подвести итог.'
# Getting summary of the_white_guard
# len(data) = 116474, wanted <= 4000
# len(data) = 831, wanted <= 4000
# Summary of the_white_guard = 'Это фрагмент книги сюрреалистического и абсурдного тона. В тексте описывается ряд событий и людей, так или иначе связанных с идеей смерти и потери разума. Есть упоминание о пророке по имени Дехтяренко, полном самоуглубленного пьянства и странных слов и предсказывающем великую перемену в мире. В тексте также упоминается человек по имени Сенкевич, который становится видимым в облаках и своим горьким смехом издевается над народом. Есть также упоминания о красных павлинах, еврейском шинкаре и форме умственного вырождения, называемой «черовщина».
#
# Текст написан в стиле потока сознания, со смесью фрагментированных предложений, пунктуационных ошибок и сюрреалистических образов. Автор словно исследует тему упадка и утраты разума, а также абсурдности человеческого существования.'
# Getting summary of war_and_peace_3_4
# len(data) = 374270, wanted <= 4000
# len(data) = 862, wanted <= 4000
# Summary of war_and_peace_3_4 = 'В этом отрывке Наполеон Бонапарт описывается как человек, который является не только великим полководцем, но также человеком культуры и интеллекта. Он изображен как человек, интересующийся обычаями и традициями людей, с которыми он сталкивается, и беседует с молодым казаком о войне между Францией и Россией. Казаку импонируют знания и проницательность Наполеона, и он слушает его с большим вниманием. Наполеон показан как харизматичный лидер, обладающий талантом располагать к себе людей своим обаянием и остроумием. Его также изображают как человека, который ценит свободу и индивидуальность, поскольку он награждает казака свободой, а не наказывает его за непослушание. В целом, этот отрывок представляет Наполеона как уверенного и способного лидера, способного общаться с людьми разного происхождения и культур.'
# Getting summary of anna_karenina
# len(data) = 453504, wanted <= 4000
# len(data) = 1553, wanted <= 4000
# Summary of anna_karenina = 'Этот текст представляет собой набор из 96 фраз, каждая из которых состоит из одного предложения. Фразы представляют собой смесь распространенных выражений, идиом и культурных отсылок, некоторые из которых можно считать юмористическими или сатирическими. Вот краткое изложение фраз:
#
# 1. «Насмешливый» (англ. «На носу») — фраза, используемая для описания чего-то очевидного или простого.
# 2. «Обидной лес» (англ. «Несчастный лес») — термин, обозначающий молодой, низкорослый лес, пригодный только для мелкой дичи.
# 3. «Трансцендентные понятия» (англ. «Трансцендентные концепции») — философские идеи, выходящие за пределы эмпирического познания.
# 4. «Обидная цена» (англ. «Убыточная цена») — фраза, используемая для описания несправедливой или завышенной цены, взимаемой за что-либо.
# 5. «Сочесть пески, лучи планет...» (англ. «...смешивать песок, лучи планет...») - фраза, используемая для передачи идеи о невозможности или неподвластности человека.
# 6. «Эти увеселительные...» (англ. «Эти развлекательные...») — фраза, используемая для описания чего-то приятного или развлекательного.
# 7. «Офицерские скачки с препятствиями...» (англ. «Офицер бежит с препятствиями...») - фраза, используемая для описания гонки или соревнования между офицерами, возможно, с препятствиями, которые нужно преодолеть.
# 8. «Ну что Фру-Фру?» (Английский: «Что такое Фру-Фру?») — фраза, используемая для того, чтобы попросить разъяснений или объяснений чего-либо.
#
# В целом фразы в этом тексте представляют собой смесь общих выражений, идиом и культурных отсылок, которые могут использоваться в повседневной речи или в творческом письме.'
# Getting summary of dead_souls
# len(data) = 186401, wanted <= 4000
# len(data) = 1186, wanted <= 4000
# Summary of dead_souls = 'Это краткое содержание повести Гоголя «Визит ревизора», действие которой происходит в вымышленном городе Н., где главный герой Чириков навещает своего знакомого Собакевича, только что назначенного налоговым инспектором. В центре сюжета их разговор, в ходе которого Чириков высмеивает новую роль Собакевича и высмеивает бюрократический язык, используемый в официальных документах. Эта история известна использованием сатиры и карикатуры для критики российского общества и политики того времени.
#
# Резюме включает в себя следующие пункты:
#
# 1. Чириков посещает Собакевича, только что назначенного налоговым инспектором.
# 2. Чириков высмеивает новую роль Собакевича и высмеивает бюрократический язык, используемый в официальных документах.
# 3. В сюжете используются сатира и карикатура для критики российского общества и политики того времени.
# 4. Персонажи используют необычные слова и фразы, такие как «фортунка» (игра слова «фортуна») и «шчильник» (выдуманное слово).
# 5. Насмешки Чирикова – это способ прокомментировать абсурдность бюрократической системы в России того времени.
# 6. Эта история известна использованием сатиры и карикатуры для критики российского общества и политики того времени.'
# Getting summary of war_and_peace_1_2
# len(data) = 382945, wanted <= 4000
# len(data) = 857, wanted <= 4000
# Summary of war_and_peace_1_2 = 'Текст представляет собой сатирический комментарий к военным походам Наполеона Бонапарта. Автор использует иронию и сарказм для критики тактики Наполеона и его веры в собственную непобедимость. В тексте также высмеивается идея «правой руки» Наполеона, Биллибина, которого изображают неуклюжим и некомпетентным офицером.
#
# Автор утверждает, что военные успехи Наполеона обусловлены не его собственной гениальностью, а слабостью его врагов. Текст также высмеивает хвастовство Наполеона о непобедимости, предполагая, что он слишком самоуверен и недооценивает своих противников.
#
# На протяжении всего текста автор использует юмор и сатиру для критики военной стратегии Наполеона и его образа себя как великого лидера. Тон беззаботный и игривый, но суть ясна: высокомерие и чрезмерная самоуверенность Наполеона в конечном итоге приведут к его падению.'
# Getting summary of the_gulag_archipelago
# len(data) = 118346, wanted <= 4000
# len(data) = 1153, wanted <= 4000
# Summary of the_gulag_archipelago = 'В резюме излагаются основные моменты, обсуждаемые в тексте. Вот краткое изложение основных представленных идей:
#
# 1. Автор описывает свой личный опыт жизни в небольшом городке России, где он стал свидетелем различных происшествий и познакомился с интересными людьми.
# 2. Автор рассказывает историю о фермере по имени Лысенко, обвиненном во вредительстве и арестованном властями.
# 3. Затем автор делится анекдотами о других людях, которых они встречали, в том числе о пожилом мужчине, у которого был уникальный способ борьбы со снегом, и генерале, который, несмотря на полученные ранения, пережил жестокое избиение.
# 4. Автор также упоминает постановление советского правительства от 1937 года, предписывавшее казнить любого, подозреваемого в диверсии или контрреволюционной деятельности.
# 5. В заключение автор заявляет, что за время своего пребывания в России они видели много странных и интересных вещей и что страна имеет богатую историю необычных явлений.
#
# В целом, в резюме освещаются личный опыт автора и анекдоты о людях, которых он встретил в России, а также о сложной истории и политическом климате страны.'
# Getting summary of and_quiet_flows_the_don
# len(data) = 703955, wanted <= 4000
# len(data) = 980, wanted <= 4000
# Summary of and_quiet_flows_the_don = 'В этом отрывке из «Войны и мира» Льва Толстого рассказчик описывает группу солдат, идущих на передовую. По пути они встречают несколько трупов, в том числе одного солдата, который все еще жив, но тяжело ранен. Солдаты потрясены и опечалены видом трупов и продолжают свой путь с дурным предчувствием.
#
# Отрывок включает в себя некоторую русскую лексику и фразы, такие как «сосна» (сосна), «газ» (газ), «окопы» (траншея), «жратва» (добыча) и «зенит» (укрытие). Рассказчик также использует некоторую военную терминологию, например, «подъесаул» (подйомен) и «станицы» (рота).
#
# Тон отрывка мрачный и задумчивый, с акцентом на суровые реалии войны. Использование ярких образов и описательного языка создает ощущение непосредственности и интенсивности, вовлекая читателя в сцену. В целом отрывок передает ощущение разрушительных последствий войны как для солдат, так и для ландшафта.'
